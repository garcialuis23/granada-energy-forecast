# %%
import pandas as pd
df = pd.read_csv('../data/processed/consumo_granada_modelo.csv')

# Filtrar por hora 10, mes 12, día 11, zona PTS Tecnologico
fila = df[(df['hour'] == 10) & 
          (df['month'] == 12) & 
          (df['day_of_month'] == 11) & 
          (df['zona_Pts_Tecnologico'] == 1)]

print(fila[['consumption_kwh', 'temperature', 'hour', 'month', 'day_of_month']].to_string())
# Out:
#          consumption_kwh  temperature  hour  month  day_of_month
# 1468902         3156.389        10.91    10     12            11
# 1477797         2787.122         8.40    10     12            11
# 1486638         2623.848        11.05    10     12            11
# 1495483         3101.214         9.88    10     12            11
# 1504339         3525.555         9.84    10     12            11
# 1513217         3018.546         9.98    10     12            11
# 1522053         2094.720        10.96    10     12            11
# 1530901         2917.233         8.27    10     12            11
# 1539753         3225.804         6.90    10     12            11
# 1548640         3120.607        11.81    10     12            11
# 1557485         3615.285         6.53    10     12            11
